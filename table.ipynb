# %%
import pandas as pd
import numpy as np

new=pd.read_csv('/content/BIG 5 тест.csv')
new.head(3)
# Out:
#                      Timestamp Ссылка на вашу страницу ВКонтакте  \
# 0  2024/10/10 3:38:29 PM GMT+3             https://vk.com/n_i1ya
# 1  2024/10/10 3:48:38 PM GMT+3           https://vk.com/egor4ekx
# 2  2024/10/10 8:54:29 PM GMT+3         https://vk.com/de_fomin_7
#
#    Я — душа компании  Я легко поддаюсь стрессу  \
# 0                  4                         2
# 1                  3                         3
# 2                  4                         1
#
#    Меня мало волнует судьба других  Я всегда подготавливаюсь заранее  \
# 0                                3                                 4
# 1                                2                                 3
# 2                                5                                 3
#
#    У меня богатый словарный запас  Я не говорю много  \
# 0                               4                  3
# 1                               4                  3
# 2                               4                  5
#
# ...

# %%
new.rename(columns={"Ссылка на вашу страницу ВКонтакте":"вк",
"Я — душа компании":"E1",
"Я не говорю много":"E2",
"Я чувствую себя комфортно среди людей":"E3",
"Я остаюсь в тени":"E4",
"Я могу начать разговор":"E5",
"Я обычно не многословен":"E6",
"На вечеринках я общаюсь со многими разными людьми":"E7",
"Я не люблю привлекать к себе внимание":"E8",
"Я не против быть в центре внимания":"E9",
"Я веду себя тихо с незнакомыми людьми":"E10",

"Я легко поддаюсь стрессу":"N1",
"Большую часть времени я расслаблен":"N2",
"Я беспокоюсь о разных вещах":"N3",
"Я редко чувствую себя подавленным":"N4",
"Меня легко вывести из себя":"N5",
"Меня легко расстроить":"N6",
"У меня часто меняется настроение":"N7",
"У меня часто происходят перепады настроения":"N8",
"Я легко раздражаюсь":"N9",
"Я часто чувствую себя подавленным":"N10",

"Меня мало волнует судьба других":"A1",
"Меня интересуют люди":"A2",
"Я оскорбляю людей":"A3",
"Я сочувствую другим":"A4",
"Меня не интересуют чужие проблемы":"A5",
"У меня мягкое сердце":"A6",
"Меня на самом деле не интересуют другие":"A7",
"Я уделяю время другим":"A8",
"Я чувствую эмоции других":"A9",
"Я помогаю людям чувствовать себя непринужденно":"A10",

"Я всегда подготавливаюсь заранее":"C1",
"Я забываю свои вещи":"C2",
"Я обращаю внимание на детали":"C3",
"Я все порчу":"C4",
"Я сразу же приступаю к выполнению домашних дел":"C5",
"Я часто забываю класть вещи на место":"C6",
"Я люблю порядок":"C7",
"Я уклоняюсь от своих обязанностей":"C8",
"Я следую расписанию":"C9",
"Я требователен к своей работе":"C10",

"У меня богатый словарный запас":"O1",
"Мне трудно понимать абстрактные идеи":"O2",
"У меня живое воображение":"O3",
"Меня не интересуют абстрактные идеи":"O4",
"У меня есть превосходные идеи":"O5",
"У меня не очень хорошее воображение":"O6",
"Я быстро все понимаю":"O7",
"Я использую сложные слова":"O8",
"Я провожу время, размышляя о различных вещах":"O9",
"Я полон идей":"O10"
                 }, inplace=True)
new.head()
# Out:
#                       Timestamp                          вк  E1  N1  A1  C1  \
# 0   2024/10/10 3:38:29 PM GMT+3       https://vk.com/n_i1ya   4   2   3   4
# 1   2024/10/10 3:48:38 PM GMT+3     https://vk.com/egor4ekx   3   3   2   3
# 2   2024/10/10 8:54:29 PM GMT+3   https://vk.com/de_fomin_7   4   1   5   3
# 3  2024/10/11 10:14:01 AM GMT+3       https://vk.com/s0phya   3   4   5   4
# 4  2024/10/11 11:09:54 AM GMT+3  https://vk.com/id127788765   4   1   3   2
#
#    O1  E2  N2  A2  ...  E9  N9  A9  C9  O9  E10  N10  A10  C10  O10
# 0   4   3   4   5  ...   4   2   4   4   5    4    2    4    4    4
# 1   4   3   5   5  ...   4   3   5   2   5    4    2    2    4    5
# 2   4   5   5   5  ...   5   1   5   4   4    1    1    3    5    5
# 3   3   2   4   5  ...   3   2   4   3   4    5    2    1    5    3
# 4   4   2   4   5  ...   4   2   5   4   4    4    2    3    4    3
#
# [5 rows x 52 columns]

# %%
new['вк'] = new['вк'].str.replace(r'https://vk.com/id', '', regex=True) #map(lambda x: x.lstrip('https://vk.com/').rstrip('aAbBcC'))
new['вк'] = new['вк'].str.replace(r'https://vk.com/', '', regex=True)
new['вк'] = new['вк'].str.replace(r'vk.com/', '', regex=True)
new['вк'] = new['вк'].str.replace(r'@', '', regex=True)
new = new[new['вк'].apply(lambda x: len(x) >= 2)]
new
# Out:
#                        Timestamp                      вк  E1  N1  A1  C1  O1  \
# 0    2024/10/10 3:38:29 PM GMT+3                  n_i1ya   4   2   3   4   4
# 1    2024/10/10 3:48:38 PM GMT+3                egor4ekx   3   3   2   3   4
# 2    2024/10/10 8:54:29 PM GMT+3              de_fomin_7   4   1   5   3   4
# 3   2024/10/11 10:14:01 AM GMT+3                  s0phya   3   4   5   4   3
# 4   2024/10/11 11:09:54 AM GMT+3               127788765   4   1   3   2   4
# 5   2024/10/11 11:16:00 AM GMT+3                 skylazh   5   4   2   3   3
# 6   2024/10/11 12:06:56 PM GMT+3                  grikaa   4   5   2   5   4
# 7   2024/10/11 12:54:27 PM GMT+3               545960785   3   4   2   4   3
# 8   2024/10/11 12:55:22 PM GMT+3         dasha.bespalova   4   1   5   3   4
# 9   2024/10/11 12:57:11 PM GMT+3               503430788   5   3   1   4   5
# 10  2024/10/11 12:57:40 PM GMT+3           issssssssaeva   4   4   2   3   5
# ...

# %%
new['E_rezult'] = new['E1'] - new['E2'] + new['E3'] - new['E4'] + new['E5'] - new['E6'] + new['E7'] - new['E8'] + new['E9'] - new['E10']
new.head(10)
# Out:
# <ipython-input-203-84dd828038e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['E_rezult'] = new['E1'] - new['E2'] + new['E3'] - new['E4'] + new['E5'] - new['E6'] + new['E7'] - new['E8'] + new['E9'] - new['E10']
#                       Timestamp               вк  E1  N1  A1  C1  O1  E2  N2  \
# 0   2024/10/10 3:38:29 PM GMT+3           n_i1ya   4   2   3   4   4   3   4
# 1   2024/10/10 3:48:38 PM GMT+3         egor4ekx   3   3   2   3   4   3   5
# 2   2024/10/10 8:54:29 PM GMT+3       de_fomin_7   4   1   5   3   4   5   5
# 3  2024/10/11 10:14:01 AM GMT+3           s0phya   3   4   5   4   3   2   4
# 4  2024/10/11 11:09:54 AM GMT+3        127788765   4   1   3   2   4   2   4
# ...

# %%
new['N_rezult'] = new['N1'] - new['N2'] + new['N3'] - new['N4'] + new['N5'] + new['N6'] + new['N7'] + new['N8'] + new['N9'] + new['N10']
new.head()
# Out:
# <ipython-input-204-670f049293c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['N_rezult'] = new['N1'] - new['N2'] + new['N3'] - new['N4'] + new['N5'] + new['N6'] + new['N7'] + new['N8'] + new['N9'] + new['N10']
#                       Timestamp          вк  E1  N1  A1  C1  O1  E2  N2  A2  \
# 0   2024/10/10 3:38:29 PM GMT+3      n_i1ya   4   2   3   4   4   3   4   5
# 1   2024/10/10 3:48:38 PM GMT+3    egor4ekx   3   3   2   3   4   3   5   5
# 2   2024/10/10 8:54:29 PM GMT+3  de_fomin_7   4   1   5   3   4   5   5   5
# 3  2024/10/11 10:14:01 AM GMT+3      s0phya   3   4   5   4   3   2   4   5
# 4  2024/10/11 11:09:54 AM GMT+3   127788765   4   1   3   2   4   2   4   5
#
# ...

# %%
new['A_rezult'] = - new['A1'] + new['A2'] - new['A3'] + new['A4'] - new['A5'] + new['A6'] - new['A7'] + new['A8'] + new['A9'] + new['A10']
new.head()
# Out:
# <ipython-input-205-c06b87a9d82c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['A_rezult'] = - new['A1'] + new['A2'] - new['A3'] + new['A4'] - new['A5'] + new['A6'] - new['A7'] + new['A8'] + new['A9'] + new['A10']
#                       Timestamp          вк  E1  N1  A1  C1  O1  E2  N2  A2  \
# 0   2024/10/10 3:38:29 PM GMT+3      n_i1ya   4   2   3   4   4   3   4   5
# 1   2024/10/10 3:48:38 PM GMT+3    egor4ekx   3   3   2   3   4   3   5   5
# 2   2024/10/10 8:54:29 PM GMT+3  de_fomin_7   4   1   5   3   4   5   5   5
# 3  2024/10/11 10:14:01 AM GMT+3      s0phya   3   4   5   4   3   2   4   5
# 4  2024/10/11 11:09:54 AM GMT+3   127788765   4   1   3   2   4   2   4   5
#
# ...

# %%
new['C_rezult'] =  new['C1'] - new['C2'] + new['C3'] - new['C4'] + new['C5'] - new['C6'] + new['C7'] - new['C8'] + new['C9'] + new['C10']
new.head()
# Out:
#                       Timestamp          вк  E1  N1  A1  C1  O1  E2  N2  A2  \
# 0   2024/10/10 3:38:29 PM GMT+3      n_i1ya   4   2   3   4   4   3   4   5
# 1   2024/10/10 3:48:38 PM GMT+3    egor4ekx   3   3   2   3   4   3   5   5
# 2   2024/10/10 8:54:29 PM GMT+3  de_fomin_7   4   1   5   3   4   5   5   5
# 3  2024/10/11 10:14:01 AM GMT+3      s0phya   3   4   5   4   3   2   4   5
# 4  2024/10/11 11:09:54 AM GMT+3   127788765   4   1   3   2   4   2   4   5
#
#    ...  O9  E10  N10  A10  C10  O10  E_rezult  N_rezult  A_rezult  C_rezult
# 0  ...   5    4    2    4    4    4         4         9        12        15
# 1  ...   5    4    2    2    4    5         1        20        19         5
# 2  ...   4    1    1    3    5    5        11        -1        11        21
# 3  ...   4    5    2    1    5    3         3        13         8        17
# 4  ...   4    4    2    3    4    3         6         4        12        14
#
# [5 rows x 56 columns]

# %%
new['O_rezult'] = new['O1'] - new['O2'] + new['O3'] - new['O4'] + new['O5'] - new['O6'] + new['O7'] + new['O8'] + new['O9'] + new['O10']
new.head()
# Out:
#                       Timestamp          вк  E1  N1  A1  C1  O1  E2  N2  A2  \
# 0   2024/10/10 3:38:29 PM GMT+3      n_i1ya   4   2   3   4   4   3   4   5
# 1   2024/10/10 3:48:38 PM GMT+3    egor4ekx   3   3   2   3   4   3   5   5
# 2   2024/10/10 8:54:29 PM GMT+3  de_fomin_7   4   1   5   3   4   5   5   5
# 3  2024/10/11 10:14:01 AM GMT+3      s0phya   3   4   5   4   3   2   4   5
# 4  2024/10/11 11:09:54 AM GMT+3   127788765   4   1   3   2   4   2   4   5
#
#    ...  E10  N10  A10  C10  O10  E_rezult  N_rezult  A_rezult  C_rezult  \
# 0  ...    4    2    4    4    4         4         9        12        15
# 1  ...    4    2    2    4    5         1        20        19         5
# 2  ...    1    1    3    5    5        11        -1        11        21
# 3  ...    5    2    1    5    3         3        13         8        17
# 4  ...    4    2    3    4    3         6         4        12        14
#
#    O_rezult
# 0        25
# 1        28
# 2        21
# 3        18
# ...

# %%
new['Выраженность'] =  abs(new['E_rezult']) + abs(new['N_rezult']) + abs(new['A_rezult']) + abs(new['C_rezult']) + abs(new['O_rezult'])
new
# Out:
#                        Timestamp                      вк  E1  N1  A1  C1  O1  \
# 0    2024/10/10 3:38:29 PM GMT+3                  n_i1ya   4   2   3   4   4
# 1    2024/10/10 3:48:38 PM GMT+3                egor4ekx   3   3   2   3   4
# 2    2024/10/10 8:54:29 PM GMT+3              de_fomin_7   4   1   5   3   4
# 3   2024/10/11 10:14:01 AM GMT+3                  s0phya   3   4   5   4   3
# 4   2024/10/11 11:09:54 AM GMT+3               127788765   4   1   3   2   4
# 5   2024/10/11 11:16:00 AM GMT+3                 skylazh   5   4   2   3   3
# 6   2024/10/11 12:06:56 PM GMT+3                  grikaa   4   5   2   5   4
# 7   2024/10/11 12:54:27 PM GMT+3               545960785   3   4   2   4   3
# 8   2024/10/11 12:55:22 PM GMT+3         dasha.bespalova   4   1   5   3   4
# 9   2024/10/11 12:57:11 PM GMT+3               503430788   5   3   1   4   5
# 10  2024/10/11 12:57:40 PM GMT+3           issssssssaeva   4   4   2   3   5
# ...

# %%
#plotdata = pd.DataFrame({"": [65, 61, 25, 22, 27]})
#plotdata.plot(kind="bar")

# %%
 #E=(value +20) / (40)
 # (value - min) / (max - min)
 #N = (value +2) / (40)
 #A= (value + 14) / (40)
 #C= (value +14) / (40)
 #O= (value +8) / (40)
 #
 #20 -20
 #38 -2
 #26 -14
 #26 -14
 #32 -8

# %%
import matplotlib.pyplot as plt
new1 = new.iloc[:6]
new1
new1.plot(x="вк", y=["E_rezult","N_rezult","A_rezult","C_rezult","O_rezult"], kind="bar")
# Out:
# <Axes: xlabel='вк'>

# %%
new.loc[:,"O_rezult"].mean()
# Out:
# 19.275

# %%
new.loc[:,"E_rezult"].mean()
# Out:
# 2.75

# %%
new.loc[:,"A_rezult"].mean()
# Out:
# 14.3

# %%
from sklearn import preprocessing

# %%
'''new2=new.iloc[2, -6:-1]
new2[new2 < 0] = 0.1
new2
new2.plot(kind='pie', subplots=True, autopct='%1.0f%%', label ='') '''
# Out:
# "new2=new.iloc[2, -6:-1]\nnew2[new2 < 0] = 0.1\nnew2\nnew2.plot(kind='pie', subplots=True, autopct='%1.0f%%', label ='') "

# %%
new2=new.iloc[28, -6:-1] #извлекает из таблицы строки 2–5 и столбцы 3–4.
#valye=np.array(new2)
#df_minmax = (new2 - new2.min()) / (new2.max() - new2.min())
'''df_minmax=df_minmax.rename(columns={'E_rezult': 'Экстраверсия',
                                    'N_rezult': 'Невротизм',
                                    'A_rezult': 'Доброжелательность',
                                    'C_rezult': 'Добросовестность',
                                    'O_rezult': 'Открытость'
                                    })'''
new2[new2 < 0] = 0.1
#df1 = pd.DataFrame(data=df_minmax.index, columns=['качество'])
df2 = pd.DataFrame(data=new2.values, columns=[' '])
#df = pd.merge(df1, df2, left_index=True, right_index=True)
#df
df2 = df2.transpose()
df2 = df2.rename(columns={0: 'Экстраверсия',
                                    1: 'Невротизм',
                                    2: 'Доброжелательность',
                                    3: 'Добросовестность',
                                    4: 'Открытость'
                                    })

df2 = df2.transpose()
#df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})
#norm=preprocessing.normalize([valye])
#normdf=pd.DataFrame(df_minmax,columns=["Экстраверсия","Невротизм","Доброжелательность","Добросовестность","Открытость"])


df2.plot(kind='pie', subplots=True, autopct='%1.0f%%', label ='', legend=False)
# Out:
# <ipython-input-218-a60bd7fd943f>:29: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2.plot(kind='pie', subplots=True, autopct='%1.0f%%', label ='', legend=False)
# array([<Axes: ylabel=' '>], dtype=object)

# %%
new3=new.iloc[28, -6:-1]
value=np.array(new3)
norm=preprocessing.normalize([value])
normdf=pd.DataFrame(norm,columns=["Экстраверсия","Невротизм","Доброжелательность","Добросовестность","Открытость"])
normdf = normdf.transpose()

# %%
#E=(value +20)/(40)

# %%
#normdf.plot(kind='pie', subplots=True, autopct='%1.0f%%', label ='', legend=False)
